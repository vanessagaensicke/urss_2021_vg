# %%
# dictionary final state

'''amo = {
    'molecule_name'={
        atom_count:,
        box_length:,
        residues={
            'res1'={
                'Atom1'={
                    'uniqueID':,
                    'coordinates':[]
                }
            }
        }
    }
}


# populated with one drug, aceclofenac

amo = {
    'aceclofenac'={
        atom_count:8202,
        box_length:4.52041,
        residues={
            'acec1'={
                'C1'={
                    'uniqueID':1,
                    'coordinates'=[3.727, 3.591, 1.026]
                }
            }
        }
    },
    'next_drug'
}'''
# Out:
# "acec1_atoms = {\n    'C1'=[identifier, x, y, z],\n    'C2'=[identifer, x, y, z]\n}\n\nacec_res = {\n    '1acec'= [acec1_atoms],\n    '2acec'= [acec2_atoms]\n}\n\namo = {\n    'aceclofenac':[atom_count, acec_res, box_length],    \n}"

# %%
# import relevant packages
import numpy as np
import pandas as pd

# %%
res = []; atm = []; atm_id = []; x = []; y = []; z = []; coord = []

# %%
with open('aceclofenac_eq1.gro') as gro:
    # skip first line, contains no relevant information
    next(gro)
    # store second line as total atoms in drug
    atom_count = int(next(gro))
    for line in gro:
        # if/else to distinguish between residue data and box length
        if 'acec' in line:
            # remove new line character and split into categories 
            col = line.strip().split()
            res.append(col[0])
            atm.append(col[1])
            atm_id.append(col[2])
            x.append(col[3])
            y.append(col[4])
            z.append(col[5])
            coord.append(col[3:6]
        # final line stored as box length   
        else:
            box_length=line.split()[0]

# %%
# one dictionary created here, how to loop for dictionary creation?
acec1_test={
    
}

# 216 unique residues in each sample, len(set(res))
# 38 atoms per residue for acec, len(set(atm))

for i in range(216):
    # narrows down to a set of 38
    if f'{i+1}acec' in res:
        for atom in atm:
            atom_index = (atm.index(atom))
            acec1_test[atom]={
                'atom_id':atm_id[atom_index],
                'coord':coord[atom_index]
            }
            
print(acec1_test)
# Out:
# {'C1': {'atom_id': '1', 'coord': ['3.727', '3.591', '1.026']}, 'C2': {'atom_id': '2', 'coord': ['3.618', '3.670', '0.989']}, 'C3': {'atom_id': '3', 'coord': ['3.582', '3.775', '1.081']}, 'C4': {'atom_id': '4', 'coord': ['3.668', '3.813', '1.185']}, 'C5': {'atom_id': '5', 'coord': ['3.786', '3.742', '1.206']}, 'C6': {'atom_id': '6', 'coord': ['3.814', '3.629', '1.129']}, 'C7': {'atom_id': '7', 'coord': ['3.875', '3.784', '1.314']}, 'C8': {'atom_id': '8', 'coord': ['3.956', '3.906', '1.268']}, 'O1': {'atom_id': '9', 'coord': ['3.978', '3.927', '1.151']}, 'O2': {'atom_id': '10', 'coord': ['3.985', '3.979', '1.370']}, 'C9': {'atom_id': '11', 'coord': ['4.022', '4.116', '1.329']}, 'C10': {'atom_id': '12', 'coord': ['3.900', '4.204', '1.285']}, 'O3': {'atom_id': '13', 'coord': ['3.781', '4.185', '1.311']}, 'O4': {'atom_id': '14', 'coord': ['3.929', '4.314', '1.205']}, 'N': {'atom_id': '15', 'coord': ['3.637', '3.927', '1.265']}, 'C11': {'atom_id': '16', 'coord': ['3.515', '3.935', '1.330']}, 'C12': {'atom_id': '17', 'coord': ['3.476', '3.849', '1.431']}, 'C13': {'atom_id': '18', 'coord': ['3.354', '3.864', '1.490']}, 'C14': {'atom_id': '19', 'coord': ['3.264', '3.966', '1.448']}, 'C15': {'atom_id': '20', 'coord': ['3.298', '4.054', '1.340']}, 'C16': {'atom_id': '21', 'coord': ['3.427', '4.033', '1.281']}, 'CL1': {'atom_id': '22', 'coord': ['3.462', '4.146', '1.152']}, 'CL2': {'atom_id': '23', 'coord': ['3.578', '3.727', '1.493']}, 'H1': {'atom_id': '24', 'coord': ['3.749', '3.507', '0.962']}, 'H2': {'atom_id': '25', 'coord': ['3.556', '3.650', '0.903']}, 'H3': {'atom_id': '26', 'coord': ['3.489', '3.826', '1.060']}, 'H4': {'atom_id': '27', 'coord': ['3.902', '3.572', '1.152']}, 'H5': {'atom_id': '28', 'coord': ['3.949', '3.705', '1.338']}, 'H6': {'atom_id': '29', 'coord': ['3.829', '3.811', '1.411']}, 'H7': {'atom_id': '30', 'coord': ['4.103', '4.114', '1.252']}, 'H8': {'atom_id': '31', 'coord': ['4.066', '4.174', '1.412']}, 'H9': {'atom_id': '32', 'coord': ['3.848', '4.365', '1.192']}, 'H10': {'atom_id': '33', 'coord': ['3.694', '4.010', '1.249']}, 'H11': {'atom_id': '34', 'coord': ['3.317', '3.791', '1.560']}, 'H12': {'atom_id': '35', 'coord': ['3.162', '3.972', '1.483']}, 'H13': {'atom_id': '36', 'coord': ['3.240', '4.138', '1.305']}, 'LP1': {'atom_id': '37', 'coord': ['3.429', '4.040', '1.273']}, 'LP2': {'atom_id': '38', 'coord': ['3.480', '3.844', '1.434']}}

# %%
res_test={
    
}

for i in range(216):
    res=f'acec{i+1}'
    res_test[res]=acec1_test
print(res_test)
# Out:
# {'acec1': {'C1': {'atom_id': '1', 'coord': ['3.727', '3.591', '1.026']}, 'C2': {'atom_id': '2', 'coord': ['3.618', '3.670', '0.989']}, 'C3': {'atom_id': '3', 'coord': ['3.582', '3.775', '1.081']}, 'C4': {'atom_id': '4', 'coord': ['3.668', '3.813', '1.185']}, 'C5': {'atom_id': '5', 'coord': ['3.786', '3.742', '1.206']}, 'C6': {'atom_id': '6', 'coord': ['3.814', '3.629', '1.129']}, 'C7': {'atom_id': '7', 'coord': ['3.875', '3.784', '1.314']}, 'C8': {'atom_id': '8', 'coord': ['3.956', '3.906', '1.268']}, 'O1': {'atom_id': '9', 'coord': ['3.978', '3.927', '1.151']}, 'O2': {'atom_id': '10', 'coord': ['3.985', '3.979', '1.370']}, 'C9': {'atom_id': '11', 'coord': ['4.022', '4.116', '1.329']}, 'C10': {'atom_id': '12', 'coord': ['3.900', '4.204', '1.285']}, 'O3': {'atom_id': '13', 'coord': ['3.781', '4.185', '1.311']}, 'O4': {'atom_id': '14', 'coord': ['3.929', '4.314', '1.205']}, 'N': {'atom_id': '15', 'coord': ['3.637', '3.927', '1.265']}, 'C11': {'atom_id': '16', 'coord': ['3.515', '3.935', '1.330']}, 'C12': {'atom_id': '17', 'coord': ['3.476', '3.849', '1.431']}, 'C13': {'atom_id': '18', 'coord': ['3.354', '3.864', '1.490']}, 'C14': {'atom_id': '19', 'coord': ['3.264', '3.966', '1.448']}, 'C15': {'atom_id': '20', 'coord': ['3.298', '4.054', '1.340']}, 'C16': {'atom_id': '21', 'coord': ['3.427', '4.033', '1.281']}, 'CL1': {'atom_id': '22', 'coord': ['3.462', '4.146', '1.152']}, 'CL2': {'atom_id': '23', 'coord': ['3.578', '3.727', '1.493']}, 'H1': {'atom_id': '24', 'coord': ['3.749', '3.507', '0.962']}, 'H2': {'atom_id': '25', 'coord': ['3.556', '3.650', '0.903']}, 'H3': {'atom_id': '26', 'coord': ['3.489', '3.826', '1.060']}, 'H4': {'atom_id': '27', 'coord': ['3.902', '3.572', '1.152']}, 'H5': {'atom_id': '28', 'coord': ['3.949', '3.705', '1.338']}, 'H6': {'atom_id': '29', 'coord': ['3.829', '3.811', '1.411']}, 'H7': {'atom_id': '30', 'coord': ['4.103', '4.114', '1.252']}, 'H8': {'atom_id': '31', 'coord': ['4.066', '4.174', '1.412']}, 'H9': {'atom_id': '32', 'coord': ['3.848', '4.365', '1.192']}, 'H10': {'atom_id': '33', 'coord': ['3.694', '4.010', '1.249']}, 'H11': {'atom_id': '34', 'coord': ['3.317', '3.791', '1.560']}, 'H12': {'atom_id': '35', 'coord': ['3.162', '3.972', '1.483']}, 'H13': {'atom_id': '36', 'coord': ['3.240', '4.138', '1.305']}, 'LP1': {'atom_id': '37', 'coord': ['3.429', '4.040', '1.273']}, 'LP2': {'atom_id': '38', 'coord': ['3.480', '3.844', '1.434']}}, 'acec2': {'C1': {'atom_id': '1', 'coord': ['3.727', '3.591', '1.026']}, 'C2': {'atom_id': '2', 'coord': ['3.618', '3.670', '0.989']}, 'C3': {'atom_id': '3', 'coord': ['3.582', '3.775', '1.081']}, 'C4': {'atom_id': '4', 'coord': ['3.668', '3.813', '1.185']}, 'C5': {'atom_id': '5', 'coord': ['3.786', '3.742', '1.206']}, 'C6': {'atom_id': '6', 'coord': ['3.814', '3.629', '1.129']}, 'C7': {'atom_id': '7', 'coord': ['3.875', '3.784', '1.314']}, 'C8': {'atom_id': '8', 'coord': ['3.956', '3.906', '1.268']}, 'O1': {'atom_id': '9', 'coord': ['3.978', '3.927', '1.151']}, 'O2': {'atom_id': '10', 'coord': ['3.985', '3.979', '1.370']}, 'C9': {'atom_id': '11', 'coord': ['4.022', '4.116', '1.329']}, 'C10': {'atom_id': '12', 'coord': ['3.900', '4.204', '1.285']}, 'O3': {'atom_id': '13', 'coord': ['3.781', '4.185', '1.311']}, 'O4': {'atom_id': '14', 'coord': ['3.929', '4.314', '1.205']}, 'N': {'atom_id': '15', 'coord': ['3.637', '3.927', '1.265']}, 'C11': {'atom_id': '16', 'coord': ['3.515', '3.935', '1.330']}, 'C12': {'atom_id': '17', 'coord': ['3.476', '3.849', '1.431']}, 'C13': {'atom_id': '18', 'coord': ['3.354', '3.864', '1.490']}, 'C14': {'atom_id': '19', 'coord': ['3.264', '3.966', '1.448']}, 'C15': {'atom_id': '20', 'coord': ['3.298', '4.054', '1.340']}, 'C16': {'atom_id': '21', 'coord': ['3.427', '4.033', '1.281']}, 'CL1': {'atom_id': '22', 'coord': ['3.462', '4.146', '1.152']}, 'CL2': {'atom_id': '23', 'coord': ['3.578', '3.727', '1.493']}, 'H1': {'atom_id': '24', 'coord': ['3.749', '3.507', '0.962']}, 'H2': {'atom_id': '25', 'coord': ['3.556', '3.650', '0.903']}, 'H3': ...

# %%
import os.path

# %%
def read_gro(filename):
    global nat, sym, pos
    f = open(filename, 'r')
    nat = int(f.readline())
    sym=[]
    pos=np.zeros((nat, 3))
    f.readline()
    for i in range(0, nat):
        line = f.readline()
        line_s = line.split()
        sym.append(line_s[0])
        pos[[i], [0]]=floatO

# %%
# working cell
# Out:
# 215

# %%
# discarded code
res_test={
    
}

res_label=[]
for i in range(216):
    res_label.append(f'{i+1}acec')

for i in res_label:
    res_index = res_label.index(i)
    res_test[res_label[res_in]]={}
    if f'acec{res_in+1}' in res:
        for a in atom:
            index = (atom.index(a))
            res_test[res_label[res_in]][a]=[atom_ident[index], coordinate[index]]
# Out:
# {'216acec': {}}

# %%
# misc commands
set(atm)
len(set(atm))
# Out:
# 38

# %%
# edit filename as store as a string
# loop through given folder

# %%
# pandas trial


# add all relevant columns to DataFrame
df = pd.DataFrame(list(zip(res, atm, atm_id, x, y, z)),
                  columns=['Residue', 'Atom', 'Atom ID', 'x', 'y', 'z'])

# set atom ID to index, as it is a unique identifier
df.set_index('Atom ID')
# Out:
#          Residue Atom      x      y      z
# Atom ID
# 1          1acec   C1  3.727  3.591  1.026
# 2          1acec   C2  3.618  3.670  0.989
# 3          1acec   C3  3.582  3.775  1.081
# 4          1acec   C4  3.668  3.813  1.185
# 5          1acec   C5  3.786  3.742  1.206
# ...          ...  ...    ...    ...    ...
# 8204     216acec  H11  0.420  4.215  3.496
# 8205     216acec  H12  0.304  3.999  3.548
# 8206     216acec  H13  0.405  3.846  3.705
# 8207     216acec  LP1  0.567  3.979  3.766
# 8208     216acec  LP2  0.575  4.198  3.636
#
# [16416 rows x 5 columns]

# %%
# convert to numerical data from string for calculation
df[["x", "y", 'z']] = df[['x', 'y', 'z']].apply(pd.to_numeric)

# coordinates of acec1, C1 and C2
print(df['x'][0], df['y'][0], df['z'][0])
print(df['x'][1], df['y'][2], df['z'][2])

# distance between C1 and C2 in nm (similar approach required for H-bond distances)
((((df['x'][0]-df['x'][1])**2)+(df['y'][0]-df['y'][1])**2 + (df['z'][0]-df['z'][1])**2)**1/2)
# Out:
# 3.727 3.591 1.026
# 3.618 3.775 1.081
# 0.00974549999999998
